# %% [markdown]
# # <center> [INDICIUM] - Processo Seletivo - Lighthouse Programa de Formação em Dados (Remoto) </center>
#
# # <center> Descrição Gráfica do Dados e Análise Descritiva </center>

# %%
#Import das libs necessárias no projeto
import pandas as pd
import seaborn as sn
import numpy as np 
import math
import matplotlib.pyplot as plt
import plotly.express as px;
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from pandasql import sqldf

# %%
#Ler os dados do csv e transformar em um dataframe para possibilitar a sua manipulação
df_treino = pd.read_csv("./desafio_manutencao_preditiva_treino.csv")
df_teste = pd.read_csv("./desafio_manutencao_preditiva_teste.csv")

# %% [markdown]
# ### Parte I - Descrevendo algumas informações básicas do dataset

# %%
#resumo de valores não nulos encontrados
print(df_teste.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   udi                    3333 non-null   int64
#  1   product_id             3333 non-null   object
#  2   type                   3333 non-null   object
#  3   air_temperature_k      3333 non-null   float64
#  4   process_temperature_k  3333 non-null   float64
#  5   rotational_speed_rpm   3333 non-null   int64
#  6   torque_nm              3333 non-null   float64
#  7   tool_wear_min          3333 non-null   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 208.4+ KB
# None

# %% [markdown]
# **Ao utilizar a função info() verifica-se que nemhuma das colunas tem valor nulo. Com isso, não será necessário nemhum tratamento para dados faltantes.**

# %%
df_teste.describe()
# Out:
#                udi  air_temperature_k  process_temperature_k  \
# count  3333.000000        3333.000000            3333.000000
# mean   5012.321932         300.029763             310.031443
# std    2868.740345           2.011382               1.474842
# min       3.000000         295.300000             305.700000
# 25%    2515.000000         298.400000             308.900000
# 50%    5023.000000         300.100000             310.100000
# 75%    7470.000000         301.600000             311.100000
# max    9998.000000         304.400000             313.800000
#
#        rotational_speed_rpm    torque_nm  tool_wear_min
# count           3333.000000  3333.000000    3333.000000
# mean            1541.489649    39.843684     107.656766
# std              183.411680    10.005058      64.247195
# min             1202.000000     4.600000       0.000000
# 25%             1425.000000    33.100000      51.000000
# 50%             1503.000000    39.900000     108.000000
# 75%             1612.000000    46.600000     163.000000
# max             2861.000000    70.000000     253.000000

# %% [markdown]
# O próximo passo foi utilizar a função describe() para descrever as principais estatisticas básicas em relação ao Dataset. Com isso temos as seguintes informações:
#
# 1. Count:
# 2. Mean:
# 3. Std:
# 4. 25%:
# 5. 50%:
# 6. 75%:
# 7. Max:

# %% [markdown]
# ### Parte II - Exploratory Data Analysis (EDA)

# %%
df_teste.head()
# Out:
#     udi product_id type  air_temperature_k  process_temperature_k  \
# 0   446     L47625    L              297.5                  308.6
# 1  7076     L54255    L              300.7                  310.5
# 2  1191     L48370    L              297.2                  308.4
# 3  2618     L49797    L              299.4                  309.1
# 4  5067     L52246    L              304.1                  313.1
#
#    rotational_speed_rpm  torque_nm  tool_wear_min
# 0                  1793       26.7             70
# 1                  1536       47.4            192
# 2                  1460       42.1             41
# 3                  1670       35.9             68
# 4                  1550       30.9              9

# %% [markdown]
# 1) As primeiras estatisticas a serem discritas são as Medidas de Tendência Central: Média, Mediana e Moda que tem por objetivo definir os valores centrais do conjunto de dados e permitir que outros dados sejam comparados a essas estatisticas, podendo assim, determinar a dispersão ou distribuição da base de dados
#
# As colunas aos quais foram calculadas foram: air_temperature_k, process_temperature_k, torque_nm

# %% [markdown]
# **Porcentagem de produto por tipo**

# %%
print(np.mean(df_teste['air_temperature_k']))
# Out:
# 300.0297629762976

# %%
print(np.median(df_teste['air_temperature_k']))
# Out:
# 300.1

# %% [markdown]
# b) Gráfico de dispersão para analisar se existe uma relação entre causa e efeito entre duas variáveis numéricas.
#
# A relação entre duas variáveis pode ser positiva, negativa ou neutra, linear ou não linear.
#
# O gráfico de dispersão não mostra apenas o valor individualmente, mas mostra os dados como um todo. Sendo útil para identificar outro padrões nos dados, como outlier (pontos extremos) ou possíveis grupos entre os dados.

# %% [markdown]
# https://medium.com/@joaolggross/visualiza%C3%A7%C3%A3o-de-dados-em-python-parte-1-gr%C3%A1ficos-de-dispers%C3%A3o-e-distribui%C3%A7%C3%A3o-com-seaborn-c8636f0202b1

# %%
# Criando o ambiente do gráfico 
sn.set_style("white")
plt.figure(figsize=(10, 10))

# Gráfico de Dispersão
g = sn.scatterplot(x="air_temperature_k", y="process_temperature_k", data=df_teste)
plt.show()

# %%
#Tamanho da amostra
tamanho= len(df_teste)

# quantidade de Classes (bins)
cl = int(round(tamanho**(1/2),0))

plt.title("Histograma de air temperature in K")
plt.xlabel("Air Temperature K")
plt.ylabel("Frequências")

# Range é uma tupla indicando o intervalo das idades. alpha corresponde a saturação da cor
plt.hist(df_teste['air_temperature_k'], bins = cl, range = ( min(df_teste['air_temperature_k']), max(df_teste['air_temperature_k'])), alpha = 0.6, color = 'g')

plt.tight_layout()

plt.show()

# %%
sn.set_style("whitegrid")
sn.boxplot(x = df_teste['type'], y = df_teste['air_temperature_k'], data = df_teste)
# Out:
# <AxesSubplot:xlabel='type', ylabel='air_temperature_k'>

# %%
sn.set_style("whitegrid")
sn.boxplot(x = df_teste['type'], y = df_teste['process_temperature_k'], data = df_teste)
# Out:
# <AxesSubplot:xlabel='type', ylabel='process_temperature_k'>

# %%
sn.set_style("whitegrid")
sn.boxplot(x = df_teste['type'], y = df_teste['rotational_speed_rpm'], data = df_teste)
# Out:
# <AxesSubplot:xlabel='type', ylabel='rotational_speed_rpm'>

# %%
# Criando o ambiente do gráfico 
sn.set_style("white")
plt.figure(figsize=(10, 10))

# Gráfico de Dispersão
g = sn.scatterplot(x="rotational_speed_rpm", y="tool_wear_min", data=df_teste)
plt.show()

# %%
labels = ['L', 'M', 'H']
values = [df_teste['type'].value_counts()[0], df_teste['type'].value_counts()[1], df_teste['type'].value_counts()[2]]
colors = ['pink', 'silver', 'steelblue']
explode = (0.05, 0.05, 0.05)
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=colors, startangle = 90, explode=explode)
plt.title('Quantidade de Produto por tipo')
plt.axis('equal')
plt.legend()
plt.show()

# %%
df_teste['tool_wear_min']
# Out:
# 0        70
# 1       192
# 2        41
# 3        68
# 4         9
#        ...
# 3328    172
# 3329     91
# 3330    181
# 3331     52
# 3332     95
# Name: tool_wear_min, Length: 3333, dtype: int64

# %% [markdown]
# ### Parte III - Prediction based on the data

# %% [markdown]
# Exportando o dataframe para csv:
# https://datatofish.com/export-dataframe-to-csv/

# %% [markdown]
# **Correlação entre os dados**

# %%
corr = df_teste.corr()
fig, ax = plt.subplots(figsize=(10, 10))
sn.heatmap(corr, cmap='RdBu', annot=True, fmt=".2f")
plt.xticks(range(len(corr.columns)), corr.columns);
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
sn.pairplot(df_teste)
plt.show()

# %% [markdown]
# https://www.kaggle.com/code/tolgahancepel/boston-housing-regression-analysis
#
# https://www.kaggle.com/code/anthonypino/price-analysis-and-linear-regression

# %% [markdown]
# ### Condições de Falha

# %% [markdown]
# 1. Tool wear failure (TWF): A ferramenta será substituída por falha quando tool wear [min] for 200 - 240 minutos.

# %%
pysqldf = lambda q: sqldf(q, globals())
falha_1= pysqldf("SELECT * FROM df_teste where tool_wear_min BETWEEN 200 AND 240 order by tool_wear_min")

# %%
falha_1 = df_teste[df_teste['tool_wear_min'].between(200, 240)]
falha_1
# Out:
#        udi product_id type  air_temperature_k  process_temperature_k  \
# 53    8607     M23466    M              297.5                  308.4
# 87     589     L47768    L              297.6                  309.4
# 92    4467     L51646    L              302.8                  310.6
# 94    6584     M21443    M              301.5                  310.5
# 107   2850     L50029    L              300.4                  309.3
# ...    ...        ...  ...                ...                    ...
# 3319  6760     L53939    L              301.7                  311.0
# 3320  1683     H31096    H              297.9                  307.4
# 3323  5310     M20169    M              303.9                  313.2
# 3324  3866     H33279    H              302.6                  311.5
# 3326  6420     H35833    H              300.3                  309.9
#
#       rotational_speed_rpm  torque_nm  tool_wear_min
# 53                    1505       37.2            215
# 87                    1628       33.4            229
# 92                    1470       41.1            205
# 94                    1503       38.2            200
# 107                   1766       28.2            207
# ...                    ...        ...            ...
# 3319                  1441       44.3            208
# 3320                  1604       36.1            225
# 3323                  1422       48.0            215
# 3324                  1629       34.4            228
# 3326                  1394       46.7            210
#
# [280 rows x 8 columns]

# %% [markdown]
# 2. Heat dissipation failure (HDF): a dissipação de calor causa uma falha do processo, se a diferença entre a temperatura do ar e do processo for inferior a 8,6 K e a velocidade de rotação da ferramenta for inferior a 1380 rpm. Este é o caso de 115 pontos de dados.

# %%
cond_2 = ((df_teste['air_temperature_k'] - df_teste['process_temperature_k']) < 8.6) & (df_teste['rotational_speed_rpm']<1380)
df_teste[cond_2]
# Out:
#        udi product_id type  air_temperature_k  process_temperature_k  \
# 14    6984     M21843    M              300.7                  311.0
# 37    5531     M20390    M              302.3                  311.8
# 41    3779     M18638    M              302.4                  311.1
# 61    8329     L55508    L              298.6                  309.5
# 79    6951     H36364    H              300.7                  311.3
# ...    ...        ...  ...                ...                    ...
# 3307  9831     L57010    L              298.3                  309.3
# 3308  1335     L48514    L              299.0                  310.4
# 3310  1162     L48341    L              297.0                  307.8
# 3312  8847     M23706    M              297.4                  308.8
# 3328  5554     L52733    L              302.5                  311.9
#
#       rotational_speed_rpm  torque_nm  tool_wear_min
# 14                    1334       53.9            150
# 37                    1355       50.1            104
# 41                    1366       54.4              0
# 61                    1325       52.2            127
# 79                    1374       53.1             66
# ...                    ...        ...            ...
# 3307                  1337       56.1            206
# 3308                  1365       49.1            226
# 3310                  1316       61.2            200
# 3312                  1325       62.4            204
# 3328                  1306       59.7            172
#
# [437 rows x 8 columns]
